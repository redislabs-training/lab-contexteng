# %% [markdown]
# # Working Memory for Multi-Turn Conversations
#
# ## Introduction
#
# Consider a simple two-turn conversation with an AI course advisor:
#
# **Turn 1:**
# 👤 "What is CS002?"
# 🤖 "CS002 is Data Structures and Algorithms..."
#
# **Turn 2:**
# 👤 "What are the prerequisites for that course?"
# 🤖 ❌ "I'm not sure which course you are referring to."
#
# The agent failed because it has no memory, it is stateless, not because it lacks knowledge. Without a memory layer, every request starts fresh. The agent cannot know that "that course" refers to CS002.
#
# This is the **grounding problem**. The agent can reason, retrieve, and respond, but it cannot *maintain context* across turns. Every conversation is isolated. References like "it", "that", or "the course we just discussed" silently break.
#
# This is because Agents use Large Language Models (LLMs) and they are **stateless**, they don't remember past conversations. Every interaction starts fresh, losing valuable context about user preferences, past decisions, and conversation history.
#
# This notebook introduces [Redis Agent Memory Server (RAMS)](https://github.com/redis/agent-memory-server), a purpose-built memory layer for AI agents. You will learn how RAMS manages conversational context through a two-tier system, and implement the two LangGraph nodes that enable multi-turn conversations: `load_working_memory_node` and `save_working_memory_node`.

# %% [markdown]
# ## What You'll Learn
#
# - How RAMS implements a **two-tier memory system**: working memory (session-scoped) vs. long-term memory (cross-session)
# - The **load → process → save lifecycle** that enables multi-turn conversations
# - How to implement `load_working_memory_node` and `save_working_memory_node` as LangGraph nodes
# - How RAMS **automatically extracts and compresses facts** to long-term memory in the background
#
# ## What You'll Build
#
# A memory-enabled LangGraph agent that:
#
# 1. Loads conversation history from RAMS at the start of each turn
# 2. Uses that history to resolve context (pronouns, references, follow-ups)
# 3. Saves the new exchange back to RAMS after responding
# 4. Benefits from automatic background extraction of durable facts
#
# ## Prerequisites
#
# - Basic familiarity with Python `async`/`await`
# - Understanding of LangGraph state graphs (nodes, edges, conditional routing)
# - A running Redis Agent Memory Server instance (`http://localhost:8088`)
#
# > **Environment:** Ensure the `agent-memory-server` service is running before executing code cells.
#
# ---
#
# > **Connection to the Memory Patterns Framework:** This notebook demonstrates **Pattern 2: Background Extraction** — RAMS automatically promotes durable facts from working memory to long-term storage without any explicit agent tool calls. You will see this in action in the "Preview: Automatic Knowledge Extraction" section at the end.

# %% [markdown]
# ## Memory Architecture
#
# ### How Redis Agent Memory (RAMS) Manages Memory: The Two-Tier Model
#
# At the heart of implementing the memory infrastructure of our agent is how RAMS manages conversational context. RAMS implements a two-tier memory system:
#
# #### 1. Working Memory (Session-Scoped)
#
# Working memory represents recent conversation history for the current session. It captures the immediate context of the ongoing conversation. Each session maintains its own working memory, perfect for managing multiple concurrent conversations per user.
#
# **Example:**
# ```
# Session: session_123
# Messages:
#   1. User: "Tell me about CS401"
#   2. Agent: "CS401 is Machine Learning..."
#   3. User: "What are its prerequisites?"
#   4. Agent: "CS401 requires CS201 and MATH301"
# ```
#
# **Key Point:** Just like ChatGPT or Claude, when you return to a conversation, the working memory is still there. The conversation doesn't disappear!
#
# #### 2. Long-Term Memory (Cross-Session)
#
# On the other hand, long-term memory represents persistent facts extracted from all conversations over time. It stores important information that transcends individual conversations. Facts are automatically extracted, deduplicated, and compressed for efficient retrieval.
#
#
# **Examples:**
#
# **User-Scoped (Personalization):**
# ```
# User: student_sarah
#   - "Prefers online courses over in-person"
#   - "Major: Computer Science, focus on AI/ML"
#   - "Goal: Graduate Spring 2026"
#   - "Completed: CS101, CS201, MATH301"
# ```
#
# **Application-Scoped (Domain Knowledge):**
# ```
# Domain: course_requirements
#   - "CS401 requires CS201 as prerequisite"
#   - "Maximum course load is 18 credits per semester"
#   - "Registration opens 2 weeks before semester start"
#   - "Lab courses require campus attendance"
# ```
#
# Here's a quick comparison of the two memory types:
#
# | Working Memory | Long-Term Memory |
# |---|---|
# | Session-scoped | User-scoped OR Application-scoped |
# | Current conversation | Important facts, rules, knowledge |
# | Persists for session | Persists across sessions |
# | Full message history | Extracted knowledge (user + domain) |
# | Loaded/saved each turn | Searched when needed |
# | Challenge: Context window limits | Challenge: Storage growth |
#
# In this notebook, we'll focus exclusively on working memory. The agent will load and saves conversation history, while RAMS will extract facts to long-term storage invisibly. The next notebook (Long-Term Memory) will add explicit tools (`search_memories`, `store_memory`) for the agent to deliberately query and manipulate long-term memory, but for now, we won't need to worry about it.
#
# Once implemented, our Working Memory architecture wraps the ReAct agent with a memory layer:
#
# ```mermaid
# graph TD
#     Q[Query] --> LM[Load Working Memory]
#     LM --> IC[Classify Intent]
#     IC -->|GREETING| HG[Handle Greeting]
#     IC -->|Other| RA[ReAct Agent]
#
#     subgraph ReAct Loop
#         RA --> T1[💭 Thought: Analyze + use history]
#         T1 --> A1[🔧 Action: search_courses]
#         A1 --> O1[👁️ Observation: Results]
#         O1 --> T2[💭 Thought: Evaluate]
#         T2 --> |Need more| A1
#         T2 --> |Done| F[✅ FINISH]
#     end
#
#     F --> SM[Save Working Memory]
#     HG --> SM
#     SM --> END[Response + Reasoning Trace]
#
#     subgraph Memory Layer
#         LM -.->|Read| RAMS[(Redis Agent Memory Server)]
#         SM -.->|Write| RAMS
#     end
# ```
#
# ### The Working Memory Lifecycle
#
# With RAMS managing the storage and organization of memories, our agent needs to orchestrate when and how to interact with it. The working memory lifecycle will follow three steps on every turn:
#
# 1. Load Working Memory: At the start of each turn, the agent will load the conversation history from RAMS. This provides the immediate context for the current conversation.
#
# 2. Process: The agent will use the conversation history as input to its reasoning process. This allows it to understand references like "that course" in context.
#
# 3. Save Working Memory: After generating a response, the agent will save the new conversation turn back to RAMS. This updates the working memory for future turns.
#
# This pattern repeats on every turn:
# - **Before reasoning**: Load history to provide context
# - **During reasoning**: ReAct agent uses history ("that course" → CS002)
# - **After reasoning**: Save the new exchange for future turns
#
# ### Implementation Overview
#
# In this notebook, you'll implement the core memory infrastructure for working memory by building the following nodes:
#
# 1. **`load_working_memory_node`**
# A LangGraph node that retrieves conversation history from RAMS at the start of each turn and adds it to the agent's state.
#
# 2. **`save_working_memory_node`**
# A LangGraph node that stores the new conversation turn (user query + agent response) back to RAMS after reasoning completes.
#
# Before diving into implementation, let's review the supporting code that has already been implemented for you in the production agent. You'll focus on implementing the memory nodes, while these components handle configuration, state management, and workflow orchestration.

# %% [markdown]
# ## Implementing Working Memory
#
# ### Supporting Infrastructure
#
# There are a few pieces of supporting infrastructure in the agent code that you should be aware of.
#
# For one, we abstract away configuration details for the Redis Agent Memory Server located in the [nodes.py](../../progressive_agents/stage5_working_memory/agent/nodes.py#L55-L62) file.
#
# ```python
# def get_memory_client() -> MemoryAPIClient:
#     """Get the configured Agent Memory Server client."""
#     config = MemoryClientConfig(
#         base_url=os.getenv("AGENT_MEMORY_URL", "http://agent-memory-server:8000"),
#         default_namespace="course_qa_agent",
#     )
#     return MemoryAPIClient(config=config)
# ```
#
# Additionally, the workflow for the agent is now modified to use a TypedDict to track all state fields across nodes in the [state.py](../../progressive_agents/stage5_working_memory/agent/state.py#L28-L80) file.
#
# For implementing memory, you'll notice there are `session_id`, `student_id`, and `conversation_history` fields:
#
# ```python
# class WorkflowState(TypedDict):
#     # Core fields you'll work with:
#     session_id: str                          # Session identifier
#     student_id: str                          # User identifier
#     conversation_history: List[Dict[str, str]]  # Previous messages
#     user_query: str                          # Current question
#     agent_response: str                      # Current answer
#
#     # Plus many other fields for intent classification,
#     # entity extraction, caching, metrics, etc.
# ```
#
# This state flows through every node in the workflow, with each node reading and updating relevant fields.
#
# Lastly, the complete workflow orchestrates multiple nodes with conditional routing in the [workflow.py#L67-L100](../../progressive_agents/stage5_working_memory/agent/workflow.py#L67-L100) file. You'll implement the `load_working_memory_node` and `save_working_memory_node` functions that plug into this graph as noted below.
#
# ```python
# workflow = StateGraph(WorkflowState)
#
# # Add all nodes
# workflow.add_node("load_memory", load_working_memory_node)
# workflow.add_node("classify_intent", classify_intent_node)
# workflow.add_node("react_agent", react_agent_node)
# workflow.add_node("save_memory", save_working_memory_node)
#
# # Define flow with conditional routing
# workflow.set_entry_point("load_memory")
# workflow.add_edge("load_memory", "classify_intent")
# workflow.add_conditional_edges("classify_intent", route_after_intent, {...})
# workflow.add_edge("react_agent", "save_memory")
# workflow.add_edge("save_memory", END)
# ```
#
# Now, let's get started building them out for the agent. Run the code block below to set up the agent code for this stage.

# %%
import sys
from pathlib import Path

project_root = Path("../.." ).resolve()

stage5_path = project_root / "progressive_agents" / "stage5_working_memory"
src_path = project_root / "src"

sys.path.insert(0, str(src_path))
sys.path.insert(0, str(stage5_path))

from agent import setup_agent, create_workflow, WorkflowState, get_memory_client, MemoryMessage, WorkingMemory

print("Initializing Working Memory Agent...")
course_manager, _ = await setup_agent(auto_load_courses=True)
workflow = create_workflow(course_manager)
# Out:
# 2026-03-25 17:05:31,675 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:31,675 - course-qa-setup - INFO - Setting up Memory-Augmented Course Q&A Agent
# 2026-03-25 17:05:31,676 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:31,676 - course-qa-setup - INFO - Initializing CourseManager with Redis URL: redis://localhost:6379
# 2026-03-25 17:05:31,676 - course-qa-setup - INFO - 📇 Using index: hierarchical_courses
# 2026-03-25 17:05:31,680 - redisvl.index.index - INFO - Index already exists, not overwriting.
# Initializing Working Memory Agent...
# 2026-03-25 17:05:32,118 - course-qa-setup - INFO - 📚 Found 50 existing courses in Redis
# 2026-03-25 17:05:32,118 - course-qa-setup - INFO - ✅ CourseManager initialized with 50 courses
# 2026-03-25 17:05:32,118 - course-qa-setup - INFO - Initializing Agent Memory Server client: http://localhost:8088
# 2026-03-25 17:05:32,127 - course-qa-setup - INFO - ✅ Agent Memory Server client initialized
# 2026-03-25 17:05:32,128 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:32,128 - course-qa-setup - INFO - ✅ Memory-Augmented Course Q&A Agent setup complete
# 2026-03-25 17:05:32,129 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:32,135 - course-qa-workflow - INFO - Loaded 52 hierarchical courses for progressive disclosure

# %% [markdown]
# ## Part 1: Implementing loading the working memory
#
# The first step in our memory lifecycle is *loading* conversation history from Agent Memory Server. This happens before the agent begins reasoning, providing it with context from previous turns in the same session.
#
# The `load_working_memory_node` is a LangGraph node that:
#
# 1. Connects to Agent Memory Server using the session ID
# 2. Retrieves all previous messages from this session's working memory
# 3. Adds those messages to the agent's state as `conversation_history`
# 4. Returns the updated state with conversation context
#
# This node transforms our agent from stateless (starting fresh every time) to stateful (aware of previous turns).
#
# ### 📌 Task: Implement `load_working_memory_node`
#
# Your task is to implement the function that loads working memory from the Agent Memory Server and populates the state's conversation history.
#
# The function receives a `state` dictionary containing `session_id` and `student_id`. It will then use the Agent Memory Server client to retrieve the working memory, convert the messages to a format the agent can use, and add them to the state.
#
# You'll use `get_or_create_working_memory()` method to retrieve the session's conversation history.
#
# <details>
# <summary>🛠️ Show Implementation Details</summary>
# <br>
#
# **Step 1: Retrieve Working Memory**
#
# Call the async method `.get_or_create_working_memory()` on the memory client with three parameters:
# - `session_id`: from `state["session_id"]`
# - `user_id`: from `state["student_id"]`
# - `model_name`: use `"gpt-4o-mini"`
#
# This returns a tuple: `(metadata, working_memory)`. You only need the `working_memory` object (use `_` for the metadata you don't need).
#
# **Step 2: Extract and Format Messages**
#
# If the `working_memory` exists and has messages (`working_memory.messages`), do the following:
# 1. Create an empty list called `conversation_history`
# 2. Iterate through `working_memory.messages`
# 3. For each message, append a dictionary with `{"role": msg.role, "content": msg.content}` to the list
# 4. Set `state["conversation_history"]` to this list
#
# If no working memory exists, then set the conversation history in the state to an empty list `[]`
#
# </details>

# %%
# Import required types and functions for memory node implementation
from agent import WorkflowState, get_memory_client

# from agent_memory_client import MemoryMessage, WorkingMemory


async def load_working_memory_node(state: WorkflowState) -> WorkflowState:
    """
    Load working memory from Agent Memory Server and populate conversation history.
    
    Args:
        state: Current workflow state with session_id and student_id
        
    Returns:
        Updated state with conversation_history from working memory
    """
    session_id = state["session_id"]
    student_id = state["student_id"]
    
    try:
        # Get the memory client
        memory_client = get_memory_client()
        
        # TODO - Step 1: Retrieve working memory for this session
        _, working_memory = await memory_client.get_or_create_working_memory(
            session_id=session_id,
            user_id=student_id,
            model_name="gpt-4o-mini"
        )
        
        # TODO - Step 2: Extract and format messages
        if working_memory and working_memory.messages:
            conversation_history = [
                {"role": msg.role, "content": msg.content}
                for msg in working_memory.messages
            ]
            state["conversation_history"] = conversation_history
            print(f"✅ Loaded {len(conversation_history)} messages from working memory")
        else:
            state["conversation_history"] = []
            print("ℹ️ No previous conversation history found")
            
    except Exception as e:
        print(f"⚠️ Error loading working memory: {e}")
        state["conversation_history"] = []
    
    return state

print("✅ load_working_memory_node defined.")
# Out:
# ✅ load_working_memory_node defined.

# %% [markdown]
# <details>
# <summary>🗝️ Solution code</summary>
#
# ```python
#
# async def load_working_memory_node(state: WorkflowState) -> WorkflowState:
#     """
#     Load working memory from Agent Memory Server and populate conversation history.
#
#     Args:
#         state: Current workflow state with session_id and student_id
#
#     Returns:
#         Updated state with conversation_history from working memory
#     """
#     session_id = state["session_id"]
#     student_id = state["student_id"]
#
#     try:
#         # Get the memory client
#         memory_client = get_memory_client()
#
#         # Retrieve working memory for this session
#         _, working_memory = await memory_client.get_or_create_working_memory(
#             session_id=session_id,
#             user_id=student_id,
#             model_name="gpt-4o-mini"
#         )
#
#         # Extract and format messages
#         if working_memory and working_memory.messages:
#             conversation_history = [
#                 {"role": msg.role, "content": msg.content}
#                 for msg in working_memory.messages
#             ]
#             state["conversation_history"] = conversation_history
#             print(f"✅ Loaded {len(conversation_history)} messages from working memory")
#         else:
#             state["conversation_history"] = []
#             print("ℹ️ No previous conversation history found")
#
#     except Exception as e:
#         print(f"⚠️ Error loading working memory: {e}")
#         state["conversation_history"] = []
#
#     return state
#
# print("✅ load_working_memory_node defined.")
# ```
#
# </details>

# %% [markdown]
# ### Test the Load Node
#
# Let's verify our load node works correctly by testing both empty sessions and sessions with existing history. The test file handles setting up test data internally. Run the following code block to start the test:

# %%
# Run comprehensive load tests (empty session + session with history)
from test_load_memory import run_tests

await run_tests(load_working_memory_node)
# Out:
# 2026-03-25 17:05:32,169 - course-qa-workflow - INFO - 💾 Saving working memory for session: test-session-with-history-456
# 2026-03-25 17:05:32,169 - agent_memory_client.models - WARNING - MemoryMessage created without explicit created_at timestamp. This will become required in a future version. Please provide created_at for accurate message ordering.
# 2026-03-25 17:05:32,176 - course-qa-workflow - INFO - ✅ Saved 2 messages to working memory
# 2026-03-25 17:05:32,177 - course-qa-workflow - INFO - ⏱️ Memory save took 0.008s
# 2026-03-25 17:05:32,177 - course-qa-workflow - INFO - 💾 Saving working memory for session: test-session-with-history-456
# 2026-03-25 17:05:32,182 - course-qa-workflow - INFO - ✅ Saved 4 messages to working memory
# 2026-03-25 17:05:32,182 - course-qa-workflow - INFO - ⏱️ Memory save took 0.005s
# ============================================================
# TEST 1: Loading from empty session (no previous history)
# ============================================================
# 📋 Memory Context:
#    Session ID: test-session-empty-123
#    Student ID: student-456
#    Loading working memory...
#
# ℹ️ No previous conversation history found
# 📦 Loaded Memory Structure:
#    Conversation history: 0 messages
#    Session ID: test-session-empty-123
#    Student ID: student-456
#
# ✓ Test passed: Empty session returns no messages
#
# ============================================================
# TEST 2: Loading from session with existing history
# ============================================================
#
# 📋 Memory Context:
#    Session ID: test-session-with-history-456
#    Student ID: student-789
#    Loading working memory...
#
# ✅ Loaded 4 messages from working memory
# 📦 Loaded Memory Structure:
#    Session ID: test-session-with-history-456
#    Student ID: student-789
#    Conversation history: 4 messages
#
# 💬 Complete Conversation History (2 turns, 4 messages):
#
#    Message 1:
#    Role: user
#    Content: What is CS001?
#
#    Message 2:
#    Role: assistant
#    Content: CS001 is Introduction to Programming, covering fundamental programming concepts.
#
#    Message 3:
#    Role: user
#    Content: What are the prerequisites?
#
#    Message 4:
#    Role: assistant
#    Content: CS001 has no prerequisites - it's an introductory course.
#
# ✓ Test passed: Session with history returns all messages
#
#
# ============================================================
# ✅ All tests passed! Load node handles both scenarios correctly
# ============================================================
# True

# %% [markdown]
# ## Part 2: Implementing the Save Working Memory Node
#
# Now that we can load conversation history, we need a way to *save* new conversation turns back to the Agent Memory Server. This happens after the agent completes its response, storing both the user's question and the agent's answer.
#
# ### Understanding the Save Node
#
# The `save_working_memory_node` is a LangGraph node that:
#
# 1. Collects the complete conversation history (previous turns + current turn)
# 2. Converts messages to Agent Memory Server's format
# 3. Saves the updated working memory to the session
# 4. Triggers automatic fact extraction (Agent Memory Server analyzes the conversation and extracts important facts to long-term memory)
#
# This node ensures that each turn is persisted, so the next turn can retrieve it via the load node.
#
# #### 📌 Task: Implement `save_working_memory_node`
#
# Your task is to implement the function that saves the current conversation turn to Agent Memory Server's working memory.
#
# The function receives a `state` dictionary with `conversation_history` (previous turns), `user_query` (current question), and `agent_response` (current answer).
#
# It should combine all messages and save them to Agent Memory Server. You'll use `MemoryMessage` and `WorkingMemory` classes to format the data, then use the `.put_working_memory()` method to save it.
#
# <details>
# <summary>🛠️ Show Implementation Details</summary>
# <br>
#
# **Step 1: Build Complete Message History**
#
# Create a list called `all_messages` that combines:
# - All messages from `state.get("conversation_history", [])` (previous turns)
# - The current user message: `{"role": "user", "content": state["user_query"]}`
# - The current agent message: `{"role": "assistant", "content": state["agent_response"]}`
#
# **Step 2: Convert to Agent Memory Server Format**
#
# Create a list called `memory_messages` by converting each message dictionary to Agent Memory Server's `MemoryMessage` object:
#
# ```python
# memory_messages = [
#     MemoryMessage(role=msg["role"], content=msg["content"])
#     for msg in all_messages
# ]
# ```
#
# **Step 3: Create Working Memory Object**
#
# Create a `WorkingMemory` object with:
# - `session_id`: from `state["session_id"]`
# - `user_id`: from `state["student_id"]`
# - `messages`: the `memory_messages` list
# - `memories`: empty list `[]`
# - `data`: empty dictionary `{}`
#
# **Step 4: Save to Agent Memory Server**
#
# Call the async method `.put_working_memory()` on the memory client with four parameters:
# - `session_id`: the `session_id` variable
# - `memory`: the `working_memory` object you created
# - `user_id`: the `student_id` variable
# - `model_name`: use `"gpt-4o-mini"`
# </details>

# %%
async def save_working_memory_node(state: WorkflowState) -> WorkflowState:
    """
    Save current conversation turn to Agent Memory Server.
    
    Args:
        state: Current workflow state with conversation history and current turn
        
    Returns:
        Unchanged state (saving is a side effect)
    """
    session_id = state["session_id"]
    student_id = state["student_id"]
    
    try:
        # Get the memory client
        memory_client = get_memory_client()

        # TODO - Step 1: Build complete message history (previous + current turn)
        # Build complete message history (previous + current turn)
        all_messages = state.get("conversation_history", []).copy()
        all_messages.append({"role": "user", "content": state["user_query"]})
        all_messages.append({"role": "assistant", "content": state["agent_response"]})
        
        # Convert to Agent Memory Server format
        memory_messages = [
            MemoryMessage(role=msg["role"], content=msg["content"])
            for msg in all_messages
        ]
        # TODO - Step 2: Convert to Agent Memory Server format
        
       
        memory_messages = [
            MemoryMessage(role=msg["role"], content=msg["content"])
            for msg in all_messages
        ]
        # TODO - Step 3: Create WorkingMemory object
        working_memory = WorkingMemory(
            session_id=session_id,
            user_id=student_id,
            messages=memory_messages,
            memories=[],
            data={},
        )
        # TODO - Step 4: Save to Agent Memory Server
        # Save to Agent Memory Server
        await memory_client.put_working_memory(
            session_id=session_id,
            memory=working_memory,
            user_id=student_id,
            model_name="gpt-4o-mini",
        )

        print(f"✅ Saved {len(memory_messages)} messages to working memory")
        
    except Exception as e:
        print(f"⚠️ Error saving working memory: {e}")
    
    return state

print("✅ save_working_memory_node defined.")
# Out:
# ✅ save_working_memory_node defined.

# %% [markdown]
# <details>
# <summary>🗝️ Solution code</summary>
# <br>
#
# ```python
#
# async def save_working_memory_node(state: WorkflowState) -> WorkflowState:
#     """
#     Save current conversation turn to Agent Memory Server.
#
#     Args:
#         state: Current workflow state with conversation history and current turn
#
#     Returns:
#         Unchanged state (saving is a side effect)
#     """
#     session_id = state["session_id"]
#     student_id = state["student_id"]
#
#     try:
#         # Get the memory client
#         memory_client = get_memory_client()
#
#         # Build complete message history (previous + current turn)
#         all_messages = state.get("conversation_history", []).copy()
#         all_messages.append({"role": "user", "content": state["user_query"]})
#         all_messages.append({"role": "assistant", "content": state["agent_response"]})
#
#         # Convert to Agent Memory Server format
#         memory_messages = [
#             MemoryMessage(role=msg["role"], content=msg["content"])
#             for msg in all_messages
#         ]
#
#         # Create WorkingMemory object
#         working_memory = WorkingMemory(
#             session_id=session_id,
#             user_id=student_id,
#             messages=memory_messages,
#             memories=[],
#             data={},
#         )
#
#         # Save to Agent Memory Server
#         await memory_client.put_working_memory(
#             session_id=session_id,
#             memory=working_memory,
#             user_id=student_id,
#             model_name="gpt-4o-mini",
#         )
#
#         print(f"✅ Saved {len(memory_messages)} messages to working memory")
#
#     except Exception as e:
#         print(f"⚠️ Error saving working memory: {e}")
#
#     return state
#
# print("✅ save_working_memory_node defined.")
# ```
#
# </details>

# %% [markdown]
# ### Test the Save Node
#
# Let's verify our save node works correctly by testing both new sessions and sessions with existing history:

# %%
# Run comprehensive save tests (new session + session with history)
from test_save_memory import run_tests

await run_tests(save_working_memory_node)
# Out:
# ============================================================
# TEST 1: Saving to new session (no previous history)
# ============================================================
# 📋 Memory Context:
#    Session ID: test-save-new-session-123
#    Student ID: student-save-001
#    Previous history: 0 messages
#    Saving new turn...
#
# ✅ Saved 2 messages to working memory
# 💬 Saved Conversation Turn:
#    User: What is CS002?
#    Agent: CS002 is Data Structures and Algorithms, covering fundamental concepts like arra...
#
# ✓ Test passed: Successfully saved first turn to new session
#
# ============================================================
# TEST 2: Saving to session with existing history
# ============================================================
# 📋 Memory Context:
#    Session ID: test-save-with-history-456
#    Student ID: student-save-002
#    Previous history: 4 messages
#    Saving new turn (turn 3)...
#
# ✅ Saved 6 messages to working memory
# 📦 Complete Memory After Save:
#    Session ID: test-save-with-history-456
#    Student ID: student-save-002
#    Total messages: 6
#    (Previous: 4 + Current turn: 2)
#
# 💬 Current Turn Saved:
#    User: What are the prerequisites for CS003?
#    Agent: CS003 Computer Architecture requires CS002 as a prerequisite.
#
# ✓ Test passed: Successfully saved turn with existing history
#
#
# ============================================================
# ✅ All tests passed! Save node handles both scenarios correctly
# ============================================================
# True

# %% [markdown]
# ## Part 3: Testing Multi-Turn Conversations
#
# You've now implemented the core memory nodes that enable conversation history! While you wrote the `load_working_memory_node` and `save_working_memory_node` functions above, we won't integrate them into the workflow in this notebook. Instead, we'll use the production implementations from [nodes.py](../../progressive_agents/stage5_working_memory/agent/nodes.py) which include the same logic you just built, plus:
#
# - Additional error handling and retry logic
# - Detailed logging for debugging
# - Memory client connection pooling
# - Metrics tracking for monitoring
#
# The production workflow in [workflow.py](../../progressive_agents/stage5_working_memory/agent/workflow.py) already has these nodes integrated into the full pipeline: `Load Memory → Classify Intent → ReAct Agent → Save Memory`.

# %% [markdown]
# Now, let's run [test_react_multi_turn.py](../../progressive_agents/stage5_working_memory/test_react_multi_turn.py) which runs 4 comprehensive multi-turn conversation scenarios:
#
# 1. Pronoun Resolution Test
#    - "What is CS002?" → "What are the prerequisites for it?" → "Tell me more about the syllabus"
#    - Demonstrates how the agent resolves "it" to CS002 using conversation history
#
# 2. Follow-up Questions Test
#    - "Tell me about machine learning courses" → "Which one is best for beginners?" → "What are the prerequisites for that course?"
#    - Shows context retention across increasingly specific follow-ups
#
# 3. Comparison Across Turns Test
#    - "What is CS001?" → "What is CS002?" → "Which one should I take first?"
#    - Tests the agent's ability to compare courses mentioned in separate turns
#
# 4. Context Accumulation Test
#    - 4-turn conversation building progressively specific queries about computer vision courses
#    - Demonstrates how context accumulates and informs later responses
#
# Run the code block below to begin the test. Note that in addition to running the tests above, the `run_tests()` function will return some session_ids that we will use in the next section.

# %%
# Import and run all multi-turn conversation tests
from test_react_multi_turn import run_tests

# Run test and store session IDs for later use in compression analysis

test_session_ids = await run_tests()
# Out:
# 2026-03-25 17:05:32,212 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:32,212 - course-qa-setup - INFO - Setting up Memory-Augmented Course Q&A Agent
# 2026-03-25 17:05:32,212 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:32,212 - course-qa-setup - INFO - Initializing CourseManager with Redis URL: redis://localhost:6379
# 2026-03-25 17:05:32,212 - course-qa-setup - INFO - 📇 Using index: hierarchical_courses
# 2026-03-25 17:05:32,214 - redisvl.index.index - INFO - Index already exists, not overwriting.
# Setting up Stage 5 agent for multi-turn tests...
# 2026-03-25 17:05:33,091 - course-qa-setup - INFO - 📚 Found 50 existing courses in Redis
# 2026-03-25 17:05:33,091 - course-qa-setup - INFO - ✅ CourseManager initialized with 50 courses
# 2026-03-25 17:05:33,091 - course-qa-setup - INFO - Initializing Agent Memory Server client: http://localhost:8088
# 2026-03-25 17:05:33,095 - course-qa-setup - INFO - ✅ Agent Memory Server client initialized
# 2026-03-25 17:05:33,095 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:33,096 - course-qa-setup - INFO - ✅ Memory-Augmented Course Q&A Agent setup complete
# 2026-03-25 17:05:33,096 - course-qa-setup - INFO - ================================================================================
# 2026-03-25 17:05:33,101 - course-qa-workflow - INFO - Loaded 52 hierarchical courses for progressive disclosure
# 2026-03-25 17:05:33,108 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:33,108 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'What is CS002?...'
# 2026-03-25 17:05:33,108 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:33,111 - course-qa-workflow - INFO - 💾 Loading working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:33,121 - course-qa-workflow - INFO - 📝 No previous conversation history found
# 2026-03-25 17:05:33,121 - course-qa-workflow - INFO - ⏱️ Memory load took 0.010s
# 2026-03-25 17:05:33,124 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'What is CS002?...'
# ======================================================================
# CONVERSATION: Pronoun Resolution  (session=f2f8ad7b...)
# ======================================================================
#
# Turn 1: What is CS002?
# 2026-03-25 17:05:34,176 - course-qa-workflow - INFO - 🎯 Intent: GENERAL
# 2026-03-25 17:05:34,177 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:05:35,666 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:05:35,666 - course-qa-workflow - INFO -   Thought: The user is asking about a specific course code, CS002. I should search for it using exact match to provide detailed information about the course.
# 2026-03-25 17:05:35,666 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:05:35,667 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:05:35,667 - course-qa-workflow - INFO -    Query: CS002
# 2026-03-25 17:05:35,668 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:05:35,668 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:05:35,668 - course-qa-workflow - INFO -    Course codes: ['CS002']
# 2026-03-25 17:05:35,668 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:05:35,670 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS002']
# 2026-03-25 17:05:35,672 - course-qa-workflow - INFO - ✅ Found 1 exact matches
# 2026-03-25 17:05:35,672 - course-qa-workflow - INFO - 📊 Summary-only context: ~90 tokens
# 2026-03-25 17:05:35,672 - course-qa-workflow - INFO -    - Summaries for 1 courses
# 2026-03-25 17:05:35,672 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:05:35,673 - course-qa-workflow - INFO -    ✅ Search completed: 362 chars returned
# 2026-03-25 17:05:35,673 - course-qa-workflow - INFO -   Observation: # Course Search Results for: CS002
#
# Found 1 relevant courses:
#
#
# ### 1. CS002: Web Development Fundamentals
# **Department**: Computer Science
# **Instructor**: Noah Rhodes
# **Credits**: 3 | **Level**: begi...
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO -   Thought: I have found the course information for CS002. I can now provide a complete answer.
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 2926.67ms
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:05:37,104 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:05:37,105 - course-qa-workflow - INFO - 💾 Saving working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:37,111 - course-qa-workflow - INFO - ✅ Saved 2 messages to working memory
# 2026-03-25 17:05:37,111 - course-qa-workflow - INFO - ⏱️ Memory save took 0.006s
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - ✅ Workflow completed in 4003.95ms
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'What are the prerequisites for it?...'
# 2026-03-25 17:05:37,112 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:37,113 - course-qa-workflow - INFO - 💾 Loading working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:37,115 - course-qa-workflow - INFO - ✅ Loaded 2 messages from working memory
# 2026-03-25 17:05:37,115 - course-qa-workflow - INFO - ⏱️ Memory load took 0.002s
# 2026-03-25 17:05:37,116 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'What are the prerequisites for it?...'
# Answer: CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. It introduces web programming using HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, c
#
# Turn 2: What are the prerequisites for it?
# 2026-03-25 17:05:37,912 - course-qa-workflow - INFO - 🎯 Intent: PREREQUISITES
# 2026-03-25 17:05:37,914 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:05:39,399 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:05:39,399 - course-qa-workflow - INFO -   Thought: The user is asking about the prerequisites for CS002. I should search for CS002's prerequisites using an exact match strategy.
# 2026-03-25 17:05:39,400 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:05:39,401 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:05:39,401 - course-qa-workflow - INFO -    Query: CS002
# 2026-03-25 17:05:39,401 - course-qa-workflow - INFO -    Intent: PREREQUISITES
# 2026-03-25 17:05:39,402 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:05:39,402 - course-qa-workflow - INFO -    Course codes: ['CS002']
# 2026-03-25 17:05:39,402 - course-qa-workflow - INFO -    Info types: ['prerequisites']
# 2026-03-25 17:05:39,403 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS002']
# 2026-03-25 17:05:39,405 - course-qa-workflow - INFO - ✅ Found 1 exact matches
# 2026-03-25 17:05:39,406 - course-qa-workflow - INFO - 📋 Filtering for specific information: ['prerequisites']
# 2026-03-25 17:05:39,406 - course-qa-workflow - INFO - 📊 Hierarchical context: ~832 tokens
# 2026-03-25 17:05:39,407 - course-qa-workflow - INFO -    - Summaries for 1 courses
# 2026-03-25 17:05:39,407 - course-qa-workflow - INFO -    - Full details for top 1 courses (intent: PREREQUISITES)
# 2026-03-25 17:05:39,407 - course-qa-workflow - INFO - ✅ Progressive disclosure: targeted information based on intent!
# 2026-03-25 17:05:39,407 - course-qa-workflow - INFO -    ✅ Search completed: 3331 chars returned
# 2026-03-25 17:05:39,408 - course-qa-workflow - INFO -   Observation: # Course Search Results for: CS002
#
# ## Overview of All Matches
#
# Found 1 relevant courses:
#
#
# ### 1. CS002: Web Development Fundamentals
# **Department**: Computer Science
# **Instructor**: Noah Rhodes
# **Cr...
# 2026-03-25 17:05:40,756 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:05:40,757 - course-qa-workflow - INFO -   Thought: The search results did not provide any information about prerequisites for CS002, which means there are no prerequisites required for this course.
# 2026-03-25 17:05:40,757 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:05:40,757 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 2842.86ms
# 2026-03-25 17:05:40,757 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:05:40,757 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:05:40,759 - course-qa-workflow - INFO - 💾 Saving working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:40,765 - course-qa-workflow - INFO - ✅ Saved 4 messages to working memory
# 2026-03-25 17:05:40,766 - course-qa-workflow - INFO - ⏱️ Memory save took 0.007s
# 2026-03-25 17:05:40,767 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:40,767 - course-qa-workflow - INFO - ✅ Workflow completed in 3654.29ms
# 2026-03-25 17:05:40,767 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:05:40,767 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:40,767 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'Tell me more about the syllabus...'
# 2026-03-25 17:05:40,768 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:40,768 - course-qa-workflow - INFO - 💾 Loading working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:40,772 - course-qa-workflow - INFO - ✅ Loaded 4 messages from working memory
# 2026-03-25 17:05:40,773 - course-qa-workflow - INFO - ⏱️ Memory load took 0.004s
# 2026-03-25 17:05:40,773 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'Tell me more about the syllabus...'
# Answer: CS002 (Web Development Fundamentals) does not have any prerequisites, making it accessible to beginners without prior experience in web development.
#
# Turn 3: Tell me more about the syllabus
# 2026-03-25 17:05:41,298 - course-qa-workflow - INFO - 🎯 Intent: SYLLABUS_OBJECTIVES
# 2026-03-25 17:05:41,301 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:05:42,716 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:05:42,717 - course-qa-workflow - INFO -   Thought: The user is asking for more details about the syllabus for CS002. I should search for the syllabus and objectives of CS002 using an exact match strategy.
# 2026-03-25 17:05:42,717 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:05:42,718 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:05:42,719 - course-qa-workflow - INFO -    Query: CS002
# 2026-03-25 17:05:42,719 - course-qa-workflow - INFO -    Intent: SYLLABUS_OBJECTIVES
# 2026-03-25 17:05:42,719 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:05:42,719 - course-qa-workflow - INFO -    Course codes: ['CS002']
# 2026-03-25 17:05:42,719 - course-qa-workflow - INFO -    Info types: ['syllabus', 'objectives']
# 2026-03-25 17:05:42,720 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS002']
# 2026-03-25 17:05:42,722 - course-qa-workflow - INFO - ✅ Found 1 exact matches
# 2026-03-25 17:05:42,722 - course-qa-workflow - INFO - 📋 Filtering for specific information: ['syllabus', 'objectives']
# 2026-03-25 17:05:42,722 - course-qa-workflow - INFO - 📊 Hierarchical context: ~914 tokens
# 2026-03-25 17:05:42,723 - course-qa-workflow - INFO -    - Summaries for 1 courses
# 2026-03-25 17:05:42,723 - course-qa-workflow - INFO -    - Full details for top 1 courses (intent: SYLLABUS_OBJECTIVES)
# 2026-03-25 17:05:42,723 - course-qa-workflow - INFO - ✅ Progressive disclosure: targeted information based on intent!
# 2026-03-25 17:05:42,723 - course-qa-workflow - INFO -    ✅ Search completed: 3657 chars returned
# 2026-03-25 17:05:42,724 - course-qa-workflow - INFO -   Observation: # Course Search Results for: CS002
#
# ## Overview of All Matches
#
# Found 1 relevant courses:
#
#
# ### 1. CS002: Web Development Fundamentals
# **Department**: Computer Science
# **Instructor**: Noah Rhodes
# **Cr...
# 2026-03-25 17:05:45,850 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:05:45,851 - course-qa-workflow - INFO -   Thought: None
# 2026-03-25 17:05:45,851 - course-qa-workflow - INFO -   Action: None
# 2026-03-25 17:05:45,852 - course-qa-workflow - INFO -   Observation: Error: Unknown action 'None'. Available actions: ['search_courses']...
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO - Iteration 3:
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO -   Thought: It seems there was an error in processing my previous response. I will reattempt to provide the final answer based on the information I have.
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 8067.41ms
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO -    Iterations: 3
# 2026-03-25 17:05:49,368 - course-qa-workflow - INFO -    Reasoning steps: 3
# 2026-03-25 17:05:49,369 - course-qa-workflow - INFO - 💾 Saving working memory for session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
# 2026-03-25 17:05:49,374 - course-qa-workflow - INFO - ✅ Saved 6 messages to working memory
# 2026-03-25 17:05:49,374 - course-qa-workflow - INFO - ⏱️ Memory save took 0.005s
# 2026-03-25 17:05:49,375 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:49,375 - course-qa-workflow - INFO - ✅ Workflow completed in 8608.02ms
# 2026-03-25 17:05:49,376 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:05:49,376 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:49,376 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'Tell me about machine learning courses...'
# 2026-03-25 17:05:49,376 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:05:49,377 - course-qa-workflow - INFO - 💾 Loading working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:05:49,381 - course-qa-workflow - INFO - 📝 No previous conversation history found
# 2026-03-25 17:05:49,381 - course-qa-workflow - INFO - ⏱️ Memory load took 0.004s
# 2026-03-25 17:05:49,382 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'Tell me about machine learning courses...'
# Answer: CS002, Web Development Fundamentals, is a 14-week course designed to introduce students to the basics of web programming using HTML, CSS, and JavaScript. Here's a detailed overview of the syllabus:
#
# -
#
# ======================================================================
# CONVERSATION: Follow-up Questions  (session=fd8e1679...)
# ======================================================================
#
# Turn 1: Tell me about machine learning courses
# 2026-03-25 17:05:50,865 - course-qa-workflow - INFO - 🎯 Intent: GENERAL
# 2026-03-25 17:05:50,866 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:05:52,454 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:05:52,454 - course-qa-workflow - INFO -   Thought: The user is interested in machine learning courses. I should search for courses related to machine learning using a hybrid search strategy to get a broad overview of what's available.
# 2026-03-25 17:05:52,455 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:05:52,456 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:05:52,456 - course-qa-workflow - INFO -    Query: machine learning
# 2026-03-25 17:05:52,458 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:05:52,458 - course-qa-workflow - INFO -    Strategy: hybrid
# 2026-03-25 17:05:52,458 - course-qa-workflow - INFO -    Course codes: []
# 2026-03-25 17:05:52,458 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:05:52,459 - course-qa-workflow - INFO - 🔀 Hybrid search with entities and filters
# 2026-03-25 17:05:53,070 - course-qa-workflow - INFO - ✅ Hybrid search found 5 courses
# 2026-03-25 17:05:53,071 - course-qa-workflow - INFO - 📊 Summary-only context: ~383 tokens
# 2026-03-25 17:05:53,072 - course-qa-workflow - INFO -    - Summaries for 5 courses
# 2026-03-25 17:05:53,072 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:05:53,072 - course-qa-workflow - INFO -    ✅ Search completed: 1533 chars returned
# 2026-03-25 17:05:53,073 - course-qa-workflow - INFO -   Observation: # Course Search Results for: machine learning
#
# Found 5 relevant courses:
#
#
# ### 1. CS010: Cybersecurity Fundamentals
# **Department**: Computer Science
# **Instructor**: Ryan Munoz
# **Credits**: 3 | **Level...
# 2026-03-25 17:05:55,914 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:05:55,914 - course-qa-workflow - INFO -   Thought: The search results did not return any machine learning courses. I should try searching again with a focus on courses specifically related to machine learning, possibly adjusting the search strategy or query if needed.
# 2026-03-25 17:05:55,914 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:05:55,915 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:05:55,915 - course-qa-workflow - INFO -    Query: machine learning
# 2026-03-25 17:05:55,915 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:05:55,915 - course-qa-workflow - INFO -    Strategy: semantic_only
# 2026-03-25 17:05:55,916 - course-qa-workflow - INFO -    Course codes: []
# 2026-03-25 17:05:55,916 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:05:55,916 - course-qa-workflow - INFO - 🔍 Semantic-only search
# 2026-03-25 17:05:56,154 - course-qa-workflow - INFO - 📊 Summary-only context: ~383 tokens
# 2026-03-25 17:05:56,154 - course-qa-workflow - INFO -    - Summaries for 5 courses
# 2026-03-25 17:05:56,155 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:05:56,155 - course-qa-workflow - INFO -    ✅ Search completed: 1533 chars returned
# 2026-03-25 17:05:56,155 - course-qa-workflow - INFO -   Observation: # Course Search Results for: machine learning
#
# Found 5 relevant courses:
#
#
# ### 1. CS010: Cybersecurity Fundamentals
# **Department**: Computer Science
# **Instructor**: Ryan Munoz
# **Credits**: 3 | **Level...
# 2026-03-25 17:05:58,699 - course-qa-workflow - INFO - Iteration 3:
# 2026-03-25 17:05:58,699 - course-qa-workflow - INFO -   Thought: The search results are not returning any machine learning courses, which suggests there might be an issue with the course catalog or the search parameters. I will provide a response based on the current information and suggest checking with Redis University for more details.
# 2026-03-25 17:05:58,700 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:05:58,700 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 7833.72ms
# 2026-03-25 17:05:58,700 - course-qa-workflow - INFO -    Iterations: 3
# 2026-03-25 17:05:58,700 - course-qa-workflow - INFO -    Reasoning steps: 3
# 2026-03-25 17:05:58,702 - course-qa-workflow - INFO - 💾 Saving working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:05:58,712 - course-qa-workflow - INFO - ✅ Saved 2 messages to working memory
# 2026-03-25 17:05:58,712 - course-qa-workflow - INFO - ⏱️ Memory save took 0.011s
# 2026-03-25 17:05:58,713 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:58,713 - course-qa-workflow - INFO - ✅ Workflow completed in 9337.40ms
# 2026-03-25 17:05:58,714 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:05:58,714 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:05:58,714 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'Which one is best for beginners?...'
# 2026-03-25 17:05:58,715 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:05:58,715 - course-qa-workflow - INFO - 💾 Loading working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:05:58,720 - course-qa-workflow - INFO - ✅ Loaded 2 messages from working memory
# 2026-03-25 17:05:58,720 - course-qa-workflow - INFO - ⏱️ Memory load took 0.005s
# 2026-03-25 17:05:58,721 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'Which one is best for beginners?...'
# Answer: It seems there is an issue with retrieving machine learning courses from the current catalog. I recommend checking directly with Redis University for the most up-to-date information on machine learnin
#
# Turn 2: Which one is best for beginners?
# 2026-03-25 17:05:59,934 - course-qa-workflow - INFO - 🎯 Intent: GENERAL
# 2026-03-25 17:05:59,935 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:06:01,380 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:06:01,381 - course-qa-workflow - INFO -   Thought: The user is asking about which machine learning course is best for beginners. I should search for introductory or beginner-friendly machine learning courses in the catalog.
# 2026-03-25 17:06:01,381 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO -    Query: machine learning
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO -    Strategy: hybrid
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO -    Course codes: []
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:06:01,382 - course-qa-workflow - INFO - 🔀 Hybrid search with entities and filters
# 2026-03-25 17:06:01,690 - course-qa-workflow - INFO - ✅ Hybrid search found 5 courses
# 2026-03-25 17:06:01,690 - course-qa-workflow - INFO - 📊 Summary-only context: ~383 tokens
# 2026-03-25 17:06:01,691 - course-qa-workflow - INFO -    - Summaries for 5 courses
# 2026-03-25 17:06:01,691 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:06:01,691 - course-qa-workflow - INFO -    ✅ Search completed: 1533 chars returned
# 2026-03-25 17:06:01,691 - course-qa-workflow - INFO -   Observation: # Course Search Results for: machine learning
#
# Found 5 relevant courses:
#
#
# ### 1. CS010: Cybersecurity Fundamentals
# **Department**: Computer Science
# **Instructor**: Ryan Munoz
# **Credits**: 3 | **Level...
# 2026-03-25 17:06:04,713 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:06:04,714 - course-qa-workflow - INFO -   Thought: The search results did not return any machine learning courses. I should try searching again with a focus on beginner-friendly machine learning courses.
# 2026-03-25 17:06:04,714 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:04,715 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:04,715 - course-qa-workflow - INFO -    Query: beginner machine learning
# 2026-03-25 17:06:04,715 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:06:04,716 - course-qa-workflow - INFO -    Strategy: hybrid
# 2026-03-25 17:06:04,716 - course-qa-workflow - INFO -    Course codes: []
# 2026-03-25 17:06:04,716 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:06:04,716 - course-qa-workflow - INFO - 🔀 Hybrid search with entities and filters
# 2026-03-25 17:06:05,007 - course-qa-workflow - INFO - ✅ Hybrid search found 5 courses
# 2026-03-25 17:06:05,007 - course-qa-workflow - INFO - 📊 Summary-only context: ~372 tokens
# 2026-03-25 17:06:05,007 - course-qa-workflow - INFO -    - Summaries for 5 courses
# 2026-03-25 17:06:05,008 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:06:05,008 - course-qa-workflow - INFO -    ✅ Search completed: 1488 chars returned
# 2026-03-25 17:06:05,008 - course-qa-workflow - INFO -   Observation: # Course Search Results for: beginner machine learning
#
# Found 5 relevant courses:
#
#
# ### 1. CS010: Cybersecurity Fundamentals
# **Department**: Computer Science
# **Instructor**: Ryan Munoz
# **Credits**: 3 ...
# 2026-03-25 17:06:08,632 - course-qa-workflow - INFO - Iteration 3:
# 2026-03-25 17:06:08,633 - course-qa-workflow - INFO -   Thought: The search results still did not return any machine learning courses, especially those suitable for beginners. It seems there might be an issue with retrieving specific machine learning courses from the catalog. I should provide a general suggestion based on typical course offerings.
# 2026-03-25 17:06:08,633 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:06:08,633 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 8698.19ms
# 2026-03-25 17:06:08,633 - course-qa-workflow - INFO -    Iterations: 3
# 2026-03-25 17:06:08,634 - course-qa-workflow - INFO -    Reasoning steps: 3
# 2026-03-25 17:06:08,635 - course-qa-workflow - INFO - 💾 Saving working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:06:08,645 - course-qa-workflow - INFO - ✅ Saved 4 messages to working memory
# 2026-03-25 17:06:08,645 - course-qa-workflow - INFO - ⏱️ Memory save took 0.011s
# 2026-03-25 17:06:08,646 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:08,647 - course-qa-workflow - INFO - ✅ Workflow completed in 9932.47ms
# 2026-03-25 17:06:08,647 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:06:08,648 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:08,648 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'What are the prerequisites for that course?...'
# 2026-03-25 17:06:08,648 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:06:08,649 - course-qa-workflow - INFO - 💾 Loading working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:06:08,652 - course-qa-workflow - INFO - ✅ Loaded 4 messages from working memory
# 2026-03-25 17:06:08,652 - course-qa-workflow - INFO - ⏱️ Memory load took 0.003s
# 2026-03-25 17:06:08,653 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'What are the prerequisites for that course?...'
# Answer: Based on typical course offerings, a beginner-friendly machine learning course would usually be titled something like "Introduction to Machine Learning" or "Machine Learning Fundamentals." These cours
#
# Turn 3: What are the prerequisites for that course?
# 2026-03-25 17:06:09,349 - course-qa-workflow - INFO - 🎯 Intent: PREREQUISITES
# 2026-03-25 17:06:09,351 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:06:10,981 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:06:10,982 - course-qa-workflow - INFO -   Thought: The user is asking about prerequisites for a beginner-friendly machine learning course, which typically would not have prerequisites. However, since I don't have specific course data from Redis University, I should attempt to search for any introductory machine learning courses and their prerequisites.
# 2026-03-25 17:06:10,982 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:10,982 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:10,982 - course-qa-workflow - INFO -    Query: Introduction to Machine Learning
# 2026-03-25 17:06:10,983 - course-qa-workflow - INFO -    Intent: PREREQUISITES
# 2026-03-25 17:06:10,983 - course-qa-workflow - INFO -    Strategy: hybrid
# 2026-03-25 17:06:10,983 - course-qa-workflow - INFO -    Course codes: []
# 2026-03-25 17:06:10,983 - course-qa-workflow - INFO -    Info types: ['prerequisites']
# 2026-03-25 17:06:10,983 - course-qa-workflow - INFO - 🔀 Hybrid search with entities and filters
# 2026-03-25 17:06:11,298 - course-qa-workflow - INFO - ✅ Hybrid search found 5 courses
# 2026-03-25 17:06:11,298 - course-qa-workflow - INFO - 📋 Filtering for specific information: ['prerequisites']
# 2026-03-25 17:06:11,299 - course-qa-workflow - INFO - 📊 Hierarchical context: ~2562 tokens
# 2026-03-25 17:06:11,299 - course-qa-workflow - INFO -    - Summaries for 5 courses
# 2026-03-25 17:06:11,299 - course-qa-workflow - INFO -    - Full details for top 3 courses (intent: PREREQUISITES)
# 2026-03-25 17:06:11,299 - course-qa-workflow - INFO - ✅ Progressive disclosure: targeted information based on intent!
# 2026-03-25 17:06:11,299 - course-qa-workflow - INFO -    ✅ Search completed: 10251 chars returned
# 2026-03-25 17:06:11,300 - course-qa-workflow - INFO -   Observation: # Course Search Results for: Introduction to Machine Learning
#
# ## Overview of All Matches
#
# Found 5 relevant courses:
#
#
# ### 1. CS010: Cybersecurity Fundamentals
# **Department**: Computer Science
# **Instr...
# 2026-03-25 17:06:13,619 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:06:13,619 - course-qa-workflow - INFO -   Thought: The search did not return any courses specifically titled "Introduction to Machine Learning" or similar, which means I don't have specific prerequisite information for a beginner-friendly machine learning course. However, typically, such courses do not have prerequisites or may require basic programming knowledge. I will provide this general guidance.
# 2026-03-25 17:06:13,619 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:06:13,620 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 4268.49ms
# 2026-03-25 17:06:13,620 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:06:13,620 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:06:13,620 - course-qa-workflow - INFO - 💾 Saving working memory for session: fd8e1679-2ebc-45f3-b9c1-63493622926c
# 2026-03-25 17:06:13,625 - course-qa-workflow - INFO - ✅ Saved 6 messages to working memory
# 2026-03-25 17:06:13,626 - course-qa-workflow - INFO - ⏱️ Memory save took 0.005s
# 2026-03-25 17:06:13,626 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:13,627 - course-qa-workflow - INFO - ✅ Workflow completed in 4978.90ms
# 2026-03-25 17:06:13,627 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:06:13,627 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:13,627 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'What is CS001?...'
# 2026-03-25 17:06:13,627 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:13,628 - course-qa-workflow - INFO - 💾 Loading working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:13,632 - course-qa-workflow - INFO - 📝 No previous conversation history found
# 2026-03-25 17:06:13,632 - course-qa-workflow - INFO - ⏱️ Memory load took 0.005s
# 2026-03-25 17:06:13,633 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'What is CS001?...'
# Answer: Typically, beginner-friendly machine learning courses, such as "Introduction to Machine Learning," do not have prerequisites or may require basic programming knowledge. Since I couldn't find specific
#
# ======================================================================
# CONVERSATION: Comparison Across Turns  (session=fa240474...)
# ======================================================================
#
# Turn 1: What is CS001?
# 2026-03-25 17:06:14,070 - course-qa-workflow - INFO - 🎯 Intent: GENERAL
# 2026-03-25 17:06:14,071 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:06:15,273 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:06:15,274 - course-qa-workflow - INFO -   Thought: The user is asking about a specific course code, CS001. I should search for it using exact match to provide detailed information about the course.
# 2026-03-25 17:06:15,274 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:15,275 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:15,275 - course-qa-workflow - INFO -    Query: CS001
# 2026-03-25 17:06:15,275 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:06:15,276 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:06:15,276 - course-qa-workflow - INFO -    Course codes: ['CS001']
# 2026-03-25 17:06:15,276 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:06:15,276 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS001']
# 2026-03-25 17:06:15,280 - course-qa-workflow - INFO - ✅ Found 1 exact matches
# 2026-03-25 17:06:15,280 - course-qa-workflow - INFO - 📊 Summary-only context: ~89 tokens
# 2026-03-25 17:06:15,280 - course-qa-workflow - INFO -    - Summaries for 1 courses
# 2026-03-25 17:06:15,281 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:06:15,281 - course-qa-workflow - INFO -    ✅ Search completed: 357 chars returned
# 2026-03-25 17:06:15,281 - course-qa-workflow - INFO -   Observation: # Course Search Results for: CS001
#
# Found 1 relevant courses:
#
#
# ### 1. CS001: Introduction to Programming with Python
# **Department**: Computer Science
# **Instructor**: Allison Hill
# **Credits**: 3 | **L...
# 2026-03-25 17:06:17,038 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:06:17,039 - course-qa-workflow - INFO -   Thought: I have found the course information for CS001. I can now provide a complete answer.
# 2026-03-25 17:06:17,039 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:06:17,039 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 2968.63ms
# 2026-03-25 17:06:17,040 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:06:17,040 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:06:17,041 - course-qa-workflow - INFO - 💾 Saving working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:17,047 - course-qa-workflow - INFO - ✅ Saved 2 messages to working memory
# 2026-03-25 17:06:17,048 - course-qa-workflow - INFO - ⏱️ Memory save took 0.007s
# 2026-03-25 17:06:17,049 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:17,049 - course-qa-workflow - INFO - ✅ Workflow completed in 3421.85ms
# 2026-03-25 17:06:17,049 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:06:17,049 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:17,050 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'What is CS002?...'
# 2026-03-25 17:06:17,050 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:17,051 - course-qa-workflow - INFO - 💾 Loading working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:17,054 - course-qa-workflow - INFO - ✅ Loaded 2 messages from working memory
# 2026-03-25 17:06:17,054 - course-qa-workflow - INFO - ⏱️ Memory load took 0.004s
# 2026-03-25 17:06:17,055 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'What is CS002?...'
# Answer: CS001 is "Introduction to Programming with Python," a beginner-level course in the Computer Science department. It is taught by Allison Hill and carries 3 credits. The course is offered in a hybrid fo
#
# Turn 2: What is CS002?
# 2026-03-25 17:06:18,055 - course-qa-workflow - INFO - 🎯 Intent: GENERAL
# 2026-03-25 17:06:18,057 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:06:19,010 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:06:19,010 - course-qa-workflow - INFO -   Thought: The user is asking about a specific course code, CS002. I should search for it using exact match to provide detailed information about the course.
# 2026-03-25 17:06:19,011 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:19,012 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:19,012 - course-qa-workflow - INFO -    Query: CS002
# 2026-03-25 17:06:19,012 - course-qa-workflow - INFO -    Intent: GENERAL
# 2026-03-25 17:06:19,013 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:06:19,013 - course-qa-workflow - INFO -    Course codes: ['CS002']
# 2026-03-25 17:06:19,013 - course-qa-workflow - INFO -    Info types: []
# 2026-03-25 17:06:19,014 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS002']
# 2026-03-25 17:06:19,015 - course-qa-workflow - INFO - ✅ Found 1 exact matches
# 2026-03-25 17:06:19,016 - course-qa-workflow - INFO - 📊 Summary-only context: ~90 tokens
# 2026-03-25 17:06:19,016 - course-qa-workflow - INFO -    - Summaries for 1 courses
# 2026-03-25 17:06:19,016 - course-qa-workflow - INFO - ✅ Summary mode: overview only
# 2026-03-25 17:06:19,016 - course-qa-workflow - INFO -    ✅ Search completed: 362 chars returned
# 2026-03-25 17:06:19,016 - course-qa-workflow - INFO -   Observation: # Course Search Results for: CS002
#
# Found 1 relevant courses:
#
#
# ### 1. CS002: Web Development Fundamentals
# **Department**: Computer Science
# **Instructor**: Noah Rhodes
# **Credits**: 3 | **Level**: begi...
# 2026-03-25 17:06:20,719 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:06:20,719 - course-qa-workflow - INFO -   Thought: I have found the course information for CS002. I can now provide a complete answer.
# 2026-03-25 17:06:20,719 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:06:20,719 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 2662.24ms
# 2026-03-25 17:06:20,719 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:06:20,720 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:06:20,721 - course-qa-workflow - INFO - 💾 Saving working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:20,727 - course-qa-workflow - INFO - ✅ Saved 4 messages to working memory
# 2026-03-25 17:06:20,727 - course-qa-workflow - INFO - ⏱️ Memory save took 0.007s
# 2026-03-25 17:06:20,728 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:20,729 - course-qa-workflow - INFO - ✅ Workflow completed in 3679.14ms
# 2026-03-25 17:06:20,729 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# 2026-03-25 17:06:20,729 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:20,729 - course-qa-workflow - INFO - 🚀 Starting Memory-Augmented workflow for query: 'Which one should I take first?...'
# 2026-03-25 17:06:20,729 - course-qa-workflow - INFO - 👤 Student: test_user | 🔗 Session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:20,730 - course-qa-workflow - INFO - 💾 Loading working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:20,733 - course-qa-workflow - INFO - ✅ Loaded 4 messages from working memory
# 2026-03-25 17:06:20,733 - course-qa-workflow - INFO - ⏱️ Memory load took 0.003s
# 2026-03-25 17:06:20,734 - course-qa-workflow - INFO - 🎯 Classifying intent for: 'Which one should I take first?...'
# Answer: CS002 is "Web Development Fundamentals," a beginner-level course in the Computer Science department. It is taught by Noah Rhodes and carries 3 credits. The course is offered in an in-person format and
#
# Turn 3: Which one should I take first?
# 2026-03-25 17:06:21,273 - course-qa-workflow - INFO - 🎯 Intent: PREREQUISITES
# 2026-03-25 17:06:21,274 - course-qa-workflow - INFO - 🤖 ReAct Agent: Processing query with explicit reasoning
# 2026-03-25 17:06:23,439 - course-qa-workflow - INFO - Iteration 1:
# 2026-03-25 17:06:23,439 - course-qa-workflow - INFO -   Thought: The user is asking for advice on which course to take first between CS001 and CS002. I should check if there are any prerequisites for these courses to determine if one should be taken before the other.
# 2026-03-25 17:06:23,440 - course-qa-workflow - INFO -   Action: search_courses
# 2026-03-25 17:06:23,441 - course-qa-workflow - INFO - 🔧 Tool called: search_courses
# 2026-03-25 17:06:23,441 - course-qa-workflow - INFO -    Query:
# 2026-03-25 17:06:23,441 - course-qa-workflow - INFO -    Intent: PREREQUISITES
# 2026-03-25 17:06:23,442 - course-qa-workflow - INFO -    Strategy: exact_match
# 2026-03-25 17:06:23,442 - course-qa-workflow - INFO -    Course codes: ['CS001', 'CS002']
# 2026-03-25 17:06:23,442 - course-qa-workflow - INFO -    Info types: ['prerequisites']
# 2026-03-25 17:06:23,443 - course-qa-workflow - INFO - 🎯 Exact match search for codes: ['CS001', 'CS002']
# 2026-03-25 17:06:23,446 - course-qa-workflow - INFO - ✅ Found 2 exact matches
# 2026-03-25 17:06:23,447 - course-qa-workflow - INFO - 📋 Filtering for specific information: ['prerequisites']
# 2026-03-25 17:06:23,447 - course-qa-workflow - INFO - 📊 Hierarchical context: ~1633 tokens
# 2026-03-25 17:06:23,447 - course-qa-workflow - INFO -    - Summaries for 2 courses
# 2026-03-25 17:06:23,448 - course-qa-workflow - INFO -    - Full details for top 2 courses (intent: PREREQUISITES)
# 2026-03-25 17:06:23,448 - course-qa-workflow - INFO - ✅ Progressive disclosure: targeted information based on intent!
# 2026-03-25 17:06:23,448 - course-qa-workflow - INFO -    ✅ Search completed: 6533 chars returned
# 2026-03-25 17:06:23,448 - course-qa-workflow - INFO -   Observation: # Course Search Results for:
#
# ## Overview of All Matches
#
# Found 2 relevant courses:
#
#
# ### 1. CS001: Introduction to Programming with Python
# **Department**: Computer Science
# **Instructor**: Allison Hi...
# 2026-03-25 17:06:25,532 - course-qa-workflow - INFO - Iteration 2:
# 2026-03-25 17:06:25,532 - course-qa-workflow - INFO -   Thought: Both CS001 and CS002 are beginner-level courses with no prerequisites, so you can choose either one based on your interest. CS001 focuses on programming fundamentals using Python, while CS002 introduces web development with HTML, CSS, and JavaScript.
# 2026-03-25 17:06:25,533 - course-qa-workflow - INFO -   Action: FINISH
# 2026-03-25 17:06:25,533 - course-qa-workflow - INFO - 🤖 ReAct Agent complete in 4259.22ms
# 2026-03-25 17:06:25,533 - course-qa-workflow - INFO -    Iterations: 2
# 2026-03-25 17:06:25,533 - course-qa-workflow - INFO -    Reasoning steps: 2
# 2026-03-25 17:06:25,534 - course-qa-workflow - INFO - 💾 Saving working memory for session: fa240474-b118-4e2e-a3ff-94d564d2d76a
# 2026-03-25 17:06:25,541 - course-qa-workflow - INFO - ✅ Saved 6 messages to working memory
# 2026-03-25 17:06:25,542 - course-qa-workflow - INFO - ⏱️ Memory save took 0.007s
# 2026-03-25 17:06:25,543 - course-qa-workflow - INFO - ================================================================================
# 2026-03-25 17:06:25,543 - course-qa-workflow - INFO - ✅ Workflow completed in 4813.80ms
# 2026-03-25 17:06:25,543 - course-qa-workflow - INFO - 📊 Execution path: react_agent_completed
# Answer: Both CS001 and CS002 are beginner-level courses with no prerequisites, so you can choose either one based on your interest. If you're interested in learning programming fundamentals and Python, start
#
# ======================================================================
# ALL MULTI-TURN TESTS COMPLETE  (3 sessions)
# ======================================================================

# %% [markdown]
# ## Preview: Automatic Knowledge Extraction
#
# ### From Conversations to Persistent Knowledge
#
# Working memory is important because it captures the current session, but what happens to valuable information when the session ends? If a student spends 20 minutes discussing their interest in machine learning courses, that knowledge shouldn't disappear when they close their browser.
#
# This is where RAMS's two-tier memory system shines. Every time you call `put_working_memory()` to save a conversation turn, RAMS automatically performs several intelligent operations behind the scenes:
#
# 1. **Analyzes the Conversation Turn**
# RAMS uses an LLM to examine the user query and agent response, identifying important information worth preserving long-term.
#
# 2. **Extracts Key Facts**
# Instead of storing verbatim conversation history, RAMS extracts compressed facts:
#    - "Student is interested in machine learning courses"
#    - "Student asked about CS004 prerequisites"
#    - "Student prefers beginner-level content"
#
# 3. **Stores in Long-Term Memory**
# These facts are saved to long-term memory with vector embeddings for semantic search and graph relationships for structured queries. They persist across sessions and are available to all future conversations for that user.
#
# 4. **Deduplicates Information**
# If a student asks "What is CS002?" multiple times across turns, RAMS recognizes the redundancy and maintains a single fact rather than duplicating information.
#
# This entire pipeline happens automatically and invisibly in this notebook. You don't need to call any extraction APIs or manage the transition from working memory to long-term memory—RAMS handles it transparently when you save working memory.
#
# > **Note:** RAMS supports [multiple memory extraction strategies](https://redis.github.io/agent-memory-server/memory-extraction-strategies/) that you can configure to customize how facts are identified and stored (such as entity extraction, topic modeling, or custom extraction prompts). In this course, we use the default extraction strategy and don't explicitly configure it in our RAMS setup which allows RAMS to intelligently handle fact extraction out of the box.
#
# The automatic fact extraction also creates a powerful compression mechanism:
#
# ```
# Working Memory:                   Long-Term Memory:
# Turn 1: "What is CS004?"         → Fact: "Student interested in CS004"
#   Response: 300 tokens
# Turn 2: "Prerequisites?"         → Fact: "Student asked about prerequisites"
#   Response: 200 tokens
# Turn 3: "More details?"          → Merged with: "Student needs CS004 info"
#   Response: 250 tokens
#
# Total: ~750 tokens               Total: ~50 tokens (15x compression)
# ```
#
# Instead of loading 750 tokens of conversation history on future turns, the agent could search long-term memory and retrieve the compressed fact: "Student is interested in CS004, asked about prerequisites and details." This achieves typical 10:1 to 20:1 compression ratios, dramatically extending the effective conversation length before hitting context limits.
#
# ### Seeing Long-Term Memory in Action
#
# Let's inspect what RAMS has automatically extracted from our test conversations without us explicitly doing anything. After running the multi-turn tests above, RAMS has been analyzing and extracting facts behind the scenes:

# %%
# Query long-term memories automatically extracted by RAMS
from query_long_term_memory import query_extracted_memories, analyze_compression

# Query memories for the test user using the AMS API
# Note: query_extracted_memories is a wrapper and is not part of the AMS API/Methods. Check out the query_long_term_memory.py to see the full implementation.
memories = await query_extracted_memories(
    student_id="test_user",
    search_query="courses discussed",
    limit=20
)

# Compare token size: working memory vs long-term memory
# Use the session IDs we stored from running the tests above
if 'test_session_ids' in dir() and len(test_session_ids) > 0:
    print(f"\n🔍 Using {len(test_session_ids)} sessions from test run:")
    for session_id in test_session_ids:
        print(f"  • {session_id}")
    
    print("\n📊 Running compression analysis...\n")
    await analyze_compression(test_session_ids, student_id="test_user")
else:
    print("\n⚠️ No test_session_ids found. Run the multi-turn tests first!")
# Out:
# 🧠 Automatically Extracted Long-Term Memories:
#
# 1. CS001 carries 3 credits.
#    Topics: education, courses
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:36:43.874649+00:00
#
# 2. CS001 is a hybrid format course.
#    Topics: education, course structure
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 20:10:30.771342+00:00
#
# 3. The course CS002 is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, teaching, course format
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 19:46:31.784598+00:00
#
# 4. CS002 is a Web Development Fundamentals course introducing web programming using HTML, CSS, and JavaScript. It is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, course, web development
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:57:15.924100+00:00
#
# 5. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. The course introduces web programming using HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, course, web development
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 21:05:38.936917+00:00
#
# 6. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. It covers web programming using HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, web development, computer science
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 19:54:35.639354+00:00
#
# 7. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. The course introduces web programming using HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, web development, courses
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:35:14.624034+00:00
#
# 8. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department introduced with web programming using HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, web development, course information
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 19:39:26.193970+00:00
#
# 9. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. The course covers web programming using HTML, CSS, and JavaScript, is taught by Noah Rhodes, carries 3 credits, and is conducted in person.
#    Topics: education, web development, course details
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:30:03.018691+00:00
#
# 10. CS001 is offered in a hybrid format.
#    Topics: education, courses
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:36:43.874684+00:00
#
# 11. CS002 is Web Development Fundamentals, a beginner-level course in the Computer Science department. CS002 is taught by Noah Rhodes. CS002 carries 3 credits. The course introduces web programming using HTML, CSS, and JavaScript, and is conducted in person.
#    Topics: education, web development, courses
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 20:09:54.881252+00:00
#
# 12. CS002, known as Web Development Fundamentals, is a beginner-level course in the Computer Science department. It covers web programming with HTML, CSS, and JavaScript. The course is taught by Noah Rhodes, carries 3 credits, and is offered in-person.
#    Topics: education, computer science, web development
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:45:14.689306+00:00
#
# 13. The course CS001 is taught by Allison Hill.
#    Topics: education, faculty
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:36:43.874514+00:00
#
# 14. CS001 is an 'Introduction to Programming with Python' course taught by Allison Hill and carries 3 credits. It is offered in a hybrid format and covers programming fundamentals using Python.
#    Topics: education, programming, Python
#    Type: MemoryTypeEnum.EPISODIC
#    Created: 2026-03-25 19:47:12.952958+00:00
#
# 15. CS001 is 'Introduction to Programming with Python,' a beginner-level course in the Computer Science department. The course is taught by Allison Hill and carries 3 credits. The course is offered in a hybrid format and covers programming fundamentals using Python.
#    Topics: education, programming, Python
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 19:40:11.353469+00:00
#
# 16. CS001 is 'Introduction to Programming with Python,' a beginner-level course in the Computer Science department. It is taught by Allison Hill and carries 3 credits. The course is offered in a hybrid format and covers programming fundamentals using Python for beginners.
#    Topics: education, programming, Python
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 21:06:19.469913+00:00
#
# 17. CS001 is 'Introduction to Programming with Python,' a beginner-level course in the Computer Science department. The course is taught by Allison Hill and carries 3 credits. It is offered in a hybrid format and focuses on teaching programming fundamentals using Python.
#    Topics: education, computer science, Python programming
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:58:04.680348+00:00
#
# 18. CS001 is 'Introduction to Programming with Python,' a beginner-level course in the Computer Science department. It is taught by Allison Hill and carries 3 credits. The course is offered in a hybrid format and covers programming fundamentals using Python for beginners.
#    Topics: education, programming, Python
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 19:55:23.664152+00:00
#
# 19. CS001 is 'Introduction to Programming with Python,' a beginner-level course in the Computer Science department. It is taught by Allison Hill and carries 3 credits. The course is offered in a hybrid format and covers programming fundamentals using Python.
#    Topics: education, computer science, programming
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:31:07.097946+00:00
#
# 20. Student prefers online courses
#    Topics: preferences
#    Type: MemoryTypeEnum.SEMANTIC
#    Created: 2026-03-25 15:31:53.926519+00:00
#
# 📊 RAMS extracted 20 facts from conversations
#    These persist across sessions and compress ~10x compared to raw message history
#
# 🔍 Using 3 sessions from test run:
#   • f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
#   • fd8e1679-2ebc-45f3-b9c1-63493622926c
#   • fa240474-b118-4e2e-a3ff-94d564d2d76a
#
# 📊 Running compression analysis...
#
#
# ======================================================================
# 📊 COMPRESSION ANALYSIS: Long-Term Memory vs Working Memory
# ======================================================================
#
# Session: f2f8ad7b-003d-4e34-9b59-20bb8c6b82d5
#   Working Memory: 6 messages, 349 tokens
# Session: fd8e1679-2ebc-45f3-b9c1-63493622926c
#   Working Memory: 6 messages, 196 tokens
# Session: fa240474-b118-4e2e-a3ff-94d564d2d76a
#   Working Memory: 6 messages, 198 tokens
# Long-Term Memory: 40 facts, 1,074 tokens
#
# ======================================================================
# 📈 COMPRESSION RATIO: 0.7x
# ======================================================================
#
# Working Memory Total:   743 tokens
# Long-Term Memory Total: 1,074 tokens
# Tokens Saved:           -331 tokens (-44.5% reduction)
#
# 💡 RAMS compressed 3 conversations into 40 searchable facts
#    This is 0.7x more efficient than storing full message history!

# %% [markdown]
# <details>
# <summary>💡 Open this dropdown after running the code block to review the compression analysis</summary>
# <br>
#
# The compression analysis above demonstrates a critical principle of managing conversational context: quality over quantity. By extracting and compressing facts from verbose conversation history, RAMS enables the agent to maintain context over much longer interactions without the risk of token limits. In this case, a compression ratio of ~1-2.5x is achieved compared to storing the full message history.
#
# </details>

# %% [markdown]
# ## Wrap Up 🏁
#
# Excellent work! You've completed this notebook and transformed your agent from a single-turn reasoner into a conversational partner with persistent memory.
#
# In this stage, you learned how to:
#
# - Implement the `load_working_memory` node that retrieves conversation history from RAMS at the start of each turn
# - Implement the `save_working_memory` node that persists conversation turns back to RAMS after reasoning completes
# - Orchestrate the Load → Process → Save lifecycle that enables multi-turn conversations with context awareness
#
# You also got a preview of how RAMS automatically extracts and compresses facts from working memory to long-term memory behind the scenes.
#
# In this notebook, automatic extraction happened invisibly—useful for managing context window limits, but not directly accessible to your agent's reasoning process. The next notebook (Long-Term Memory) changes that by giving your agent *explicit control* over long-term memory via LangChain tools.
#
# You'll transform the agent from passively benefiting from automatic extraction to actively managing its own memory—deciding what to remember, what to recall, and when to search its accumulated knowledge.
